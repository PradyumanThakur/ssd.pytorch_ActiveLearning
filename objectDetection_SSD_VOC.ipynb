# %%
import random
import os

import warnings
warnings.filterwarnings("ignore")

# %%
SEED = 42
random.seed(SEED)

# %%
# !ls
# Out:
# 000007.npy    data     experiments		      ssd.py	     weights
# LICENSE       demo     inference.py		      ssd300_120000
# README.md     doc      layers			      test.py
# __pycache__   eval     objectDetection_SSD_VOC.ipynb  train.py
# acquisitions  eval.py  run_round_00.py		      utils

# %%
# %%time
# !python run_round_00.py \
    --dataset VOC \
    --seed {SEED} \
    --epochs 300 \
    --batch_size 32 \
    --num_workers 8 \
    --dataset_root ../../datasets/PASCAL_VOC/VOCdevkit/ \
    --initial-budget 1000 \
    --acquisition-budget 1000 \
    --cuda True \
    --experiment-name VOC_SSD300_{SEED}
# Out:
# ============================================================
# Creating initial split
# ============================================================
# ==================================================
# Total images : 16551
# Labeled   : 1000
# Unlabeled : 15551
# Labeled %    : 6.04%
# ==================================================
#
# Experiment created successfully at: experiments/VOC_SSD300_42
#
# Training Round 00...
#
# Using device: cuda
# /home/pradyuman/envs/activeLearning/lib/python3.10/site-packages/torch/__init__.py:1331: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# /home/pradyuman/activeLearning/objectDetection/ssd.pytorch/ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# Loading base network...
# Initializing weights...
# ============================================================
# Dataset       : VOC0712
# Training imgs : 1000
# Epochs        : 300
# Batch size    : 32
# Learning rate : 0.001
# Save dir      : experiments/VOC_SSD300_42/initial/round_00/checkpoints
#
# Starting training...
#
# Epoch [1/300]:   0%|                                    | 0/32 [00:00<?, ?it/s]/home/pradyuman/envs/activeLearning/lib/python3.10/site-packages/torch/nn/functional.py:3700: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   reduction = _Reduction.legacy_get_string(size_average, reduce)
# /home/pradyuman/envs/activeLearning/lib/python3.10/site-packages/torch/nn/functional.py:3506: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   reduction = _Reduction.legacy_get_string(size_average, reduce)
# Epoch [1/300]: 100%|█| 32/32 [00:52<00:00,  1.65s/it, conf=13.226, loc=3.141, l
#
# Epoch 001 | Loc 2.9431 | Conf 14.1636 | Total 17.1067
# Evaluating:   7%|████▉                                                                 | 11/155 [04:21<56:51, 23.69s/it]^C
# Traceback (most recent call last):
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 1209, in wait
#     return self._wait(timeout=timeout)
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 1959, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 1917, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/pradyuman/activeLearning/objectDetection/ssd.pytorch/run_round_00.py", line 199, in <module>
#     main()
#   File "/home/pradyuman/activeLearning/objectDetection/ssd.pytorch/run_round_00.py", line 112, in main
#     subprocess.run(train_cmd, check=True)
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 505, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 1146, in communicate
#     self.wait()
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 1222, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/home/pradyuman/envs/activeLearning/lib/python3.10/subprocess.py", line 1953, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
# CPU times: user 4.02 s, sys: 1.04 s, total: 5.06 s
# Wall time: 5min 32s
